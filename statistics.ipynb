# %% [markdown]
# <a href="https://colab.research.google.com/github/Rutujakodag1/Machine-Learning/blob/main/statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.mlab as mlb

# %%
a=pd.read_csv("/content/Population dataset.csv")
a.head()
# Out:
#    Bodyweight
# 0       27.03
# 1       24.80
# 2       27.02
# 3       28.07
# 4       23.55

# %%
len(a)
# Out:
# 225

# %%
a.mode()
# Out:
#    Bodyweight
# 0       23.39
# 1       24.82
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Bodyweight'].plot(kind='hist', bins=20, title='Bodyweight')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Bodyweight']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Bodyweight'}, axis=1)
#               .sort_values('Bodyweight', ascending=True))
# ...

# %%
a.median()
# Out:
# Bodyweight    23.54
# dtype: float64

# %%
a.mean()
# Out:
# Bodyweight    23.893378
# dtype: float64

# %%
n,bins,patches=plt.hist(a,bins=12,color='blue')
plt.title("Histogram of population")
plt.ylabel("no of observation")
plt.xlabel("Bodyweight")
plt.show()
